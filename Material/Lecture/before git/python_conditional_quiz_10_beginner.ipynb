# %% [markdown]
# # Python 조건문 이해도 확인 퀴즈 10문제
# 이 노트북은 **초급 Python 학습자**를 위한 조건문 연습용 퀴즈입니다.
#
# ## 안내
# - 각 문제 아래의 코드 셀에 직접 코드를 작성하세요.
# - `input()`을 사용하지 말고, 문제에서 제시한 변수에 값을 저장한 뒤 조건문으로 해결하세요.
# - 출력은 `print()`를 사용하세요.
# - 들여쓰기에 특히 주의하세요.
#
# ---

# %% [markdown]
# ## 문제 1. 양수 / 음수 / 0 판별
#
# 정수 `n`이 주어졌을 때 다음과 같이 출력하세요.
#
# - `n > 0` 이면 `"positive"`
# - `n < 0` 이면 `"negative"`
# - 그 외는 `"zero"`
#
# 예시:
# ```python
# n = -3
# # 출력: negative
# ```

# %%
n = -3

# 여기에 코드를 작성하세요

# %% [markdown]
# ## 문제 2. 짝수 / 홀수 판별
#
# 정수 `n`이 주어졌을 때 짝수이면 `"even"`, 홀수이면 `"odd"`를 출력하세요.
#
# 예시:
# ```python
# n = 7
# # 출력: odd
# ```

# %%
n = 7

# 여기에 코드를 작성하세요

# %% [markdown]
# ## 문제 3. 점수에 따른 등급 출력
#
# 점수 `score`가 주어졌을 때 다음 기준으로 등급을 출력하세요.
#
# - 90 이상: `A`
# - 80 이상 90 미만: `B`
# - 70 이상 80 미만: `C`
# - 그 외: `D`
#
# 예시:
# ```python
# score = 85
# # 출력: B
# ```

# %%
score = 85

# 여기에 코드를 작성하세요

# %% [markdown]
# ## 문제 4. 놀이기구 탑승 가능 여부
#
# 나이 `age`와 키 `height`가 주어졌을 때 다음과 같이 출력하세요.
#
# - 나이가 10 이상이고 키가 140 이상이면 `"ride"`
# - 그렇지 않으면 `"no ride"`
#
# 예시:
# ```python
# age = 11
# height = 138
# # 출력: no ride
# ```

# %%
age = 11
height = 138

# 여기에 코드를 작성하세요

# %% [markdown]
# ## 문제 5. 양수인 경우에만 짝수/홀수 판별 (nested if)
#
# 정수 `n`이 주어졌을 때 다음과 같이 출력하세요.
#
# - `n`이 양수이면
#   - 짝수이면 `"positive even"`
#   - 홀수이면 `"positive odd"`
# - 양수가 아니면 `"not positive"`
#
# 예시:
# ```python
# n = 6
# # 출력: positive even
# ```

# %%
n = 6

# 여기에 코드를 작성하세요

# %% [markdown]
# ## 문제 6. 로그인 확인 (nested if)
#
# 아이디 `user_id`와 비밀번호 `pw`가 주어졌을 때 다음과 같이 출력하세요.
#
# - `user_id`가 `"admin"`이면
#   - `pw`가 `"1234"`이면 `"login success"`
#   - 아니면 `"wrong password"`
# - `user_id`가 `"admin"`이 아니면 `"no user"`
#
# 예시:
# ```python
# user_id = "admin"
# pw = "0000"
# # 출력: wrong password
# ```

# %%
user_id = "admin"
pw = "0000"

# 여기에 코드를 작성하세요

# %% [markdown]
# ## 문제 7. 100의 자리 수에 따라 분류
#
# 세 자리 정수 `n`이 주어졌을 때, 100의 자리 숫자에 따라 다음과 같이 출력하세요.
#
# - 100의 자리가 1, 2, 3이면 `"low"`
# - 4, 5, 6이면 `"middle"`
# - 7, 8, 9이면 `"high"`
#
# 예시:
# ```python
# n = 582
# # 출력: middle
# ```
#
# 힌트: `n // 100` 을 사용할 수 있습니다.

# %%
n = 582

# 여기에 코드를 작성하세요

# %% [markdown]
# ## 문제 8. 줄 번호에 따른 자리 구분
#
# 학생 번호 `n`이 주어집니다. 한 줄에 4명씩 앉습니다.
#
# - 1~4번: 1번째 줄
# - 5~8번: 2번째 줄
# - 9~12번: 3번째 줄
# - ...
#
# 다음과 같이 출력하세요.
#
# - 3번째 줄 이하이면
#   - 학생 번호가 짝수면 `"front-even"`
#   - 홀수면 `"front-odd"`
# - 그 외는 `"back"`
#
# 예시:
# ```python
# n = 10
# # 출력: front-even
# ```
#
# 힌트: 줄 번호는 `(n - 1) // 4 + 1` 로 구할 수 있습니다.

# %%
n = 10

# 여기에 코드를 작성하세요

# %% [markdown]
# ## 문제 9. 시간에 따른 상태 출력
#
# 정수 `hour`가 주어집니다. `0`부터 `23` 사이의 값이라고 가정합니다.
#
# 다음 기준으로 출력하세요.
#
# - 9 이상 18 이하이면
#   - 12 또는 13이면 `"lunch time"`
#   - 그 외는 `"working time"`
# - 그 외는 `"closed"`
#
# 예시:
# ```python
# hour = 13
# # 출력: lunch time
# ```

# %%
hour = 13

# 여기에 코드를 작성하세요

# %% [markdown]
# ## 문제 10. 두 수 비교 후 추가 판별 (nested if)
#
# 정수 `a`, `b`가 주어졌을 때 다음과 같이 출력하세요.
#
# - `a > b` 이면
#   - 두 수의 차가 10 이상이면 `"a is much bigger"`
#   - 아니면 `"a is bigger"`
# - `a < b` 이면 `"b is bigger"`
# - 같으면 `"same"`
#
# 예시:
# ```python
# a = 25
# b = 12
# # 출력: a is much bigger
# ```

# %%
a = 25
b = 12

# 여기에 코드를 작성하세요
