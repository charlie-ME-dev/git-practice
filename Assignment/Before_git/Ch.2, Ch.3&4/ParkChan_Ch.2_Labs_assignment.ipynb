# %% [markdown]
# # Mar. 19th - 3rd week

# %% [markdown]
# ## Lab 2-1: 대화식 모드에서 출력하기

# %%
print('나의 이름은: ', ' 박찬')
print('나의 나이는 : ', 26)
print("나의 키는", 173, 'cm 입니다.')
print('10 + 20 =', 10 + 20, '10 * 20 =', 10 * 20)

# %% [markdown]
# ## Lab 2-2: 원의 면적과 둘레 구하기

# %%
print('원의 반지름', 8.0)
print('원의 면적', 3.14*8.0**2)
print('원의 둘레', 2.0*3.14*8.0)

# %% [markdown]
# ## Lab 2-3: 변수를 사용하는 프로그램

# %%
print('Lab 2-3 1번문제')
radius = 8.0
print('원의 반지름', radius)
print('원의 면적', 3.14*radius**2)
print('원의 둘레', 2.0*3.14*radius)

# %%
print('Lab 2-3 2번문제')
radius = 10.0
print('원의 둘레', 2.0*3.14*radius)
print('원의 면적', 3.14*radius**2)

# %%
print('Lab 2-3 3번문제')
width = 100
height = 200
print('너비 ',width,' 높이 ',height,'인 사각형의 면적 : ',width * height)

# %% [markdown]
# ## Lab 2-4: 다음 코드를 입력해 보고 그 출력 결과를 밑줄 부분에 적으시오.

# %%
name = '전우치'
print('나의 이름은 :', name)

# %%
age = 27
print('나의 나이는 :', age)

# %%
height = 179
print('나의 키는', height, 'cm 입니다.')

# %%
sum = 10 + 20
print('10 + 20 =', sum)

# %%
mult = 10*20
print('10 * 20 =', mult)

# %% [markdown]
# ## Lab 2-5: 다양한 식별자를 활용한 변수 사용

# %% [markdown]
# ### 1. 다음 코드를 작성하고 실행해 보자. 이 코드는 어떤 에러를 유발할까? 또 이 에러를 어떻게 수정해야 할까?

# %%
change_var = 300
print(change_var)

# %% [markdown]
# ### 2. 다음 코드는 어디에서 에러가 발생할까?

# %%
width = 20
height = 40
area = width * height
print('사각형의 면적',area)

# %% [markdown]
# ### 3. 다음 코드는 어떤 문제가 있을까?

# %%
iixxjjkk = 20
print('나의 나이는', iixxjjkk, '세 입니다')
# Q1. 이 코드는 에러를 출력하는가?(예, 아니오로 대답하여라)
# 아니오.
# Q2. 이 코드는 어떤 측면에서 문제점이 있는가?
# 변수명이 의미가 없습니다. 나이를 묻기 때문에 age 이런걸로 하면 더욱 좋을 것 같습니다.

# %% [markdown]
# ### 4. 삼각형의 면적을 구하는 다음과 같은 코드는 어떤 문제가 있을까?

# %%
radius = 20
depth = 3.14*radius**2

#Q1. 이 코드는 에러를 출력하는가?(예, 아니오로 대답하여라)
#A. 아니오
#Q2. 이 코드는 어떤 측면에서 문제점이 있는가?
#A. 변수명이 문제의 취지와 맞지 않네요. depth보다 area가 나을 것 같아요
#Q3. 이 코드의 변수 이름을 문제의 취지에 맞도록 수정하여라
#A. area로 설정하면 좋을 것 같네요.

# %% [markdown]
# ## Lab 2-6: 다양한 식별자를 활용한 변수 사용

# %% [markdown]
# ### 다음과 같은 코드는 최종적으로 어떤 결과를  출력할까? 출력 결과를 미리 예상해보고 코딩해보자.

# %%
width = 20
height = 40
width = 30
area = width * height
print('사각형의 면적', area)

#예상결과 : 사각형의 면적 1200

# %% [markdown]
# ## Lab 2-7: 파이썬 연산자의 사용

# %% [markdown]
# ### 1. 다음과 같은 계산을 파이썬 대화창에서 수행하고 그 결과를 적으시오.

# %%
123 * 456

# %%
1357 + 2468

# %%
5**4

# %%
20 / 4

# %%
20 // 5

# %%
20 % 5

# %% [markdown]
# ### 2. 5를 2로 나눈 나머지를 구하시오. 이를 구하기 위한 파이썬 수식을 적으시오.

# %%
remainder = 5 % 2
print('5를 2로 나눈 나머지 : ', remainder)

# %% [markdown]
# ### 3. 2의 제곱근 sqrt(2)와 3의 제곱근 sqrt(3)을 ** 연산자를 사용하여 각각 구하시오.

# %%
sqrt2 = 2 ** (1/2)
sqrt3 = 3 **(1/2)
print('2의 제곱근 :', sqrt2)
print('3의 제곱근 :', sqrt3)

# %% [markdown]
# ## Lab 2-8: 복소수의 연산

# %% [markdown]
# ### 1. 복소수 a = 8 + 2i, b = 4 + 3i의 두 복소수에 대하여 다음 연산 결과를 적으시오.

# %%
a = 8+2j
b = 4+3j
print(a+b)

# %%
a = 8+2j
b = 4+3j
print(a-b)

# %%
a = 8+2j
b = 4+3j
print(a*b)

# %%
a = 8+2j
b = 4+3j
print(a/b)

# %% [markdown]
# ## Lab 2-9: 비트 연산 활용

# %% [markdown]
# #### 정수를 반으로 나누어 가며 얻는 수를 계산해 보고
# #### 연속적으로 두 배를 만들어 2x 값을 생성해 보는 일을 비트 연산으로 할 수 있다.
# #### 다음과 같이 a라는 변수에 대하여 비트 연산을 적용시키고 그 결과를 밑줄 친 부분에 적어보시오.

# %%
a = 1024
a >> 1
print(a)

# %%
a>>2
print(a)

# %%
a = a>>1
a
print(a)

# %%
a = a>>1
a
print(a)

# %%
a=1
a << 1
print(a)

# %%
a = a<<1
a
print(a)

# %%
a = a<<1
a
print(a)

# %%
a = a<<1
a
print(a)

# %%
a = a<<1
a
print(a)
