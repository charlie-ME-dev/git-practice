# %% [markdown]
# # 🐍 Chapter 7 HOL — 딕셔너리, 튜플, 집합
# ## 실습용 Jupyter Notebook (학생용)
#
# 이 실습 노트북은 7장의 주요 개념을 **직접 코드로 완성하면서** 익히도록 만들어졌습니다.
#
# ### 📘 실습 진행 방법
# 1. 각 드릴(Drill)은 다음 순서로 구성됩니다.
#    - **개념 설명** (Markdown)
#    - **예시** (읽고 이해만 하세요)
#    - **🎯 Task** — 여러분이 해결할 과제
#    - **Expected Output** — 코드를 실행했을 때 나와야 하는 결과
#    - **💡 Hint** — 막힐 때 참고
# 2. 코드 셀에서 `# TODO:` 로 표시된 부분을 채워 넣으세요.
# 3. 셀을 실행(Shift + Enter)하여 Expected Output과 결과가 일치하는지 확인합니다.
# 4. 검증 코드(아래쪽의 `print(...)` 부분)는 **수정하지 마세요**.
#
# ### ✅ 학습 목표
# - 딕셔너리, 튜플, 집합 자료형을 자유롭게 다룬다
# - 리스트와 딕셔너리의 차이를 이해한다
# - 튜플 패킹/언패킹, 스왑, 함수의 다중 반환값을 활용한다
# - 집합 연산(합/교/차/대칭차)을 수행한다
# - 반복가능(iterable) 자료형과 `zip()` 함수를 이해한다
# - 튜플과 문자열의 슬라이싱을 익힌다
#
# ---

# %% [markdown]
# ## 📘 Section 1. 딕셔너리 자료형 (Dictionary)
#
# 딕셔너리는 **키(key)와 값(value)을 짝지어** 저장하는 자료형입니다. 키를 통해 값을 빠르게 찾을 수 있으며, **같은 키는 중복될 수 없습니다**.

# %% [markdown]
# ### 1.1 딕셔너리 생성하기
#
# **개념**: 딕셔너리는 중괄호 `{}` 안에 `키: 값` 형태로 항목을 넣어 만듭니다.
#
# **예시**:
# ```python
# capital = {'한국': '서울', '일본': '도쿄'}
# print(capital)
# # {'한국': '서울', '일본': '도쿄'}
# ```
#
# **🎯 Task**: 카페 메뉴 `menu` 딕셔너리를 만드세요.
# - `'아메리카노'` → `4500`
# - `'라떼'` → `5000`
# - `'녹차'` → `4000`
#
# **Expected Output**:
# ```
# {'아메리카노': 4500, '라떼': 5000, '녹차': 4000}
# 메뉴 개수: 3
# ```
#
# **💡 Hint**: 중괄호 `{}` 를 사용하고, 각 항목은 `키: 값` 으로 적고 쉼표로 구분합니다.

# %%
# TODO: menu 딕셔너리를 완성하세요
menu = {
    # '아메리카노': ____,
    # '____': 5000,
    # '녹차': ____,
}

# ↓ 검증 코드 — 수정하지 마세요
print(menu)
print("메뉴 개수:", len(menu))

# %% [markdown]
# ### 1.2 값 접근하기
#
# **개념**: `딕셔너리[키]` 형태로 값에 접근합니다.
#
# **예시**:
# ```python
# capital = {'한국': '서울', '일본': '도쿄'}
# print(capital['한국'])   # 서울
# ```
#
# **🎯 Task**: `menu` 에서 `'라떼'` 가격을 가져와 `latte_price` 변수에 넣으세요.
#
# **Expected Output**:
# ```
# 라떼 가격: 5000원
# ```
#
# **💡 Hint**: 리스트에서 인덱스 대신, 키를 사용한다고 생각하세요.

# %%
menu = {'아메리카노': 4500, '라떼': 5000, '녹차': 4000}

# TODO: 라떼의 가격을 latte_price 에 저장하세요
latte_price = # ____

print(f"라떼 가격: {latte_price}원")

# %% [markdown]
# ### 1.3 항목 삽입과 삭제
#
# **개념**:
# - 삽입/수정: `딕셔너리[새_키] = 값`
# - 삭제: `del 딕셔너리[키]`
#
# **예시**:
# ```python
# capital = {'한국': '서울'}
# capital['미국'] = '워싱턴'   # 삽입
# del capital['한국']          # 삭제
# ```
#
# **🎯 Task**:
# 1. `menu` 에 `'자몽에이드'` 를 가격 `5500` 으로 추가
# 2. `menu` 의 `'녹차'` 항목을 삭제
# 3. `'아메리카노'` 가격을 `4800` 으로 수정
#
# **Expected Output**:
# ```
# {'아메리카노': 4800, '라떼': 5000, '자몽에이드': 5500}
# ```

# %%
menu = {'아메리카노': 4500, '라떼': 5000, '녹차': 4000}

# TODO 1: '자몽에이드' 를 5500 으로 추가
# ____

# TODO 2: '녹차' 삭제
# ____

# TODO 3: '아메리카노' 가격을 4800 으로 수정
# ____

print(menu)

# %% [markdown]
# ### 1.4 딕셔너리와 연산자 — `len`, `in`, `==`
#
# **개념**:
# - `len(d)` : 항목 수
# - `키 in d` : 키가 존재하는지 확인 (True/False)
# - `d1 == d2` : 두 딕셔너리가 완전히 같은지
# - ⚠️ 딕셔너리는 `<`, `>` 같은 크기 비교 연산을 **지원하지 않습니다**.
#
# **예시**:
# ```python
# capital = {'한국': '서울', '일본': '도쿄'}
# print('한국' in capital)    # True
# ```
#
# **🎯 Task**: `menu` 에 대해 아래 값들을 계산하세요.
# - `count` : 메뉴 개수
# - `has_latte` : `'라떼'` 가 메뉴에 있는가? (True/False)
# - `no_cola` : `'콜라'` 가 메뉴에 **없는가**? (True/False)
#
# **Expected Output**:
# ```
# 메뉴 개수: 3
# 라떼 있음? True
# 콜라 없음? True
# ```

# %%
menu = {'아메리카노': 4500, '라떼': 5000, '녹차': 4000}

# TODO: 아래 세 변수에 올바른 값을 채우세요
count = # ____
has_latte = # ____
no_cola = # ____

print("메뉴 개수:", count)
print("라떼 있음?", has_latte)
print("콜라 없음?", no_cola)

# %% [markdown]
# ### 1.5 딕셔너리 메소드 — `.keys()`, `.values()`, `.items()`
#
# **개념**:
# - `.keys()` : 키들의 뷰(view)
# - `.values()` : 값들의 뷰
# - `.items()` : `(키, 값)` 튜플들의 뷰
#
# **예시**:
# ```python
# capital = {'한국': '서울', '일본': '도쿄'}
# print(list(capital.keys()))     # ['한국', '일본']
# print(list(capital.values()))   # ['서울', '도쿄']
# print(list(capital.items()))    # [('한국', '서울'), ('일본', '도쿄')]
# ```
#
# **🎯 Task**: `menu` 의 키, 값, 항목을 각각 리스트로 변환해 출력하세요.
#
# **Expected Output**:
# ```
# ['아메리카노', '라떼', '녹차']
# [4500, 5000, 4000]
# [('아메리카노', 4500), ('라떼', 5000), ('녹차', 4000)]
# ```

# %%
menu = {'아메리카노': 4500, '라떼': 5000, '녹차': 4000}

# TODO: 각 뷰를 list 로 변환해 저장하세요
keys_list = # ____
values_list = # ____
items_list = # ____

print(keys_list)
print(values_list)
print(items_list)

# %% [markdown]
# ### 1.6 `get()` 메소드로 `KeyError` 방지하기
#
# **개념**: 없는 키를 `딕셔너리[키]` 로 접근하면 `KeyError` 가 발생합니다.
# `get(키)` 또는 `get(키, 기본값)` 을 사용하면 안전하게 값을 가져올 수 있습니다.
#
# **예시**:
# ```python
# capital = {'한국': '서울'}
# print(capital.get('미국'))           # None
# print(capital.get('미국', '정보없음'))  # 정보없음
# ```
#
# **🎯 Task**:
# - `menu.get('라떼')` 결과를 `v1` 에 저장
# - `menu.get('콜라')` 결과를 `v2` 에 저장
# - `menu.get('콜라', 0)` 결과를 `v3` 에 저장
#
# **Expected Output**:
# ```
# v1 = 5000
# v2 = None
# v3 = 0
# ```

# %%
menu = {'아메리카노': 4500, '라떼': 5000, '녹차': 4000}

# TODO: v1, v2, v3 를 채우세요
v1 = # ____
v2 = # ____
v3 = # ____

print("v1 =", v1)
print("v2 =", v2)
print("v3 =", v3)

# %% [markdown]
# ### 1.7 `for ... in` 으로 딕셔너리 순회하기
#
# **개념**: 딕셔너리에 `for ... in` 을 쓰면 **키**가 하나씩 반환됩니다.
# 값도 같이 쓰고 싶다면 `.items()` 를 활용하세요.
#
# **예시**:
# ```python
# capital = {'한국': '서울', '일본': '도쿄'}
# for k, v in capital.items():
#     print(k, '->', v)
# ```
#
# **🎯 Task**: `menu` 의 모든 항목을 `"아메리카노: 4500원"` 형식으로 한 줄씩 출력하세요.
#
# **Expected Output**:
# ```
# 아메리카노: 4500원
# 라떼: 5000원
# 녹차: 4000원
# ```

# %%
menu = {'아메리카노': 4500, '라떼': 5000, '녹차': 4000}

# TODO: menu.items() 를 순회하며 출력하세요
for # ____ in # ____:
    print(f"{# ____}: {# ____}원")

# %% [markdown]
# ---
# ## 📘 Section 2. 리스트와 딕셔너리 비교
#
# 같은 정보를 **리스트**로도, **딕셔너리**로도 표현할 수 있지만, 찾고 싶을 때의 편의성이 다릅니다.

# %% [markdown]
# ### 2.1 같은 데이터를 두 가지 방식으로 표현하기
#
# **상황**: 도서관에 책 3권이 있습니다.
# - `파이썬 입문` → 재고 5권
# - `자료구조` → 재고 2권
# - `웹 프로그래밍` → 재고 8권
#
# **🎯 Task**:
# 1. 책 제목을 담은 리스트 `titles` 와 재고를 담은 리스트 `stocks` 를 만드세요. **(같은 순서로)**
# 2. 같은 정보를 딕셔너리 `library` 로도 만드세요.
# 3. `'자료구조'` 의 재고를 **두 방식으로 각각** 가져와 비교하세요.
#
# **Expected Output**:
# ```
# 리스트 방식: 2권
# 딕셔너리 방식: 2권
# ```
#
# **💡 Hint**: 리스트에서는 `'자료구조'` 의 위치(index)를 `titles.index('자료구조')` 로 구할 수 있습니다.

# %%
# TODO: 리스트 방식
titles = # ____
stocks = # ____

# TODO: 딕셔너리 방식
library = # ____

# TODO: '자료구조' 재고를 두 가지 방식으로 각각 구하기
idx = # ____                   # titles 에서 '자료구조' 의 위치
stock_by_list = # ____         # stocks[idx]
stock_by_dict = # ____         # library['자료구조']

print(f"리스트 방식: {stock_by_list}권")
print(f"딕셔너리 방식: {stock_by_dict}권")

# %% [markdown]
# ### 2.2 언제 딕셔너리가 더 적절한가?
#
# **생각해보기**: 아래 두 상황 중 **딕셔너리**가 더 자연스러운 경우는 무엇일까요?
#
# - (A) 오늘 아침에 마신 커피들을 순서대로 기록하기
# - (B) 각 학생의 학번을 키로 이메일 주소를 저장하기
#
# **🎯 Task**: 딕셔너리가 더 적절한 경우의 알파벳을 `answer` 에 문자열로 저장하세요. (`'A'` 또는 `'B'`)
#
# **Expected Output**:
# ```
# 답: B
# ```

# %%
# TODO: 'A' 또는 'B' 중 하나를 answer 에 저장하세요
answer = # ____

print("답:", answer)

# %% [markdown]
# ---
# ## 📘 Section 3. 튜플 자료형 (Tuple)
#
# 튜플은 **괄호 `()`** 로 감싼 여러 값의 모임입니다. 리스트와 비슷하지만 **한 번 만들면 바꿀 수 없다**(immutable)는 큰 차이가 있습니다.

# %% [markdown]
# ### 3.1 튜플 생성하기
#
# **개념**: 튜플은 다음과 같은 여러 가지 방법으로 만들 수 있습니다.
# ```python
# t1 = (10, 20, 30)
# t2 = 10, 20, 30         # 괄호 생략 가능
# t3 = (42,)              # ⚠️ 원소가 1개면 콤마 필수
# t4 = tuple([1, 2, 3])   # 리스트 → 튜플
# ```
#
# **🎯 Task**: 서울의 위도/경도를 튜플로 표현하세요.
# - `loc1` : `(37.56, 126.97)` 을 괄호를 써서 직접 생성
# - `loc2` : 같은 값을 괄호 없이 생성
# - `single` : 원소가 하나인 튜플 `(100,)` 을 생성
#
# **Expected Output**:
# ```
# loc1 = (37.56, 126.97)   type = <class 'tuple'>
# loc2 = (37.56, 126.97)   type = <class 'tuple'>
# single = (100,)          type = <class 'tuple'>
# ```
#
# **💡 Hint**: `single = (100)` 은 그냥 정수 100 입니다. 콤마를 잊지 마세요!

# %%
# TODO: 세 가지 방식으로 튜플을 만드세요
loc1 = # ____      # 괄호 사용
loc2 = # ____      # 괄호 생략
single = # ____    # 원소 1개 튜플

print(f"loc1 = {loc1}   type = {type(loc1)}")
print(f"loc2 = {loc2}   type = {type(loc2)}")
print(f"single = {single}          type = {type(single)}")

# %% [markdown]
# ### 3.2 인덱싱은 되지만 수정은 안 된다 (불변성)
#
# **개념**: 튜플은 `t[0]`, `t[1]` 처럼 인덱싱으로 값을 **읽을 수는** 있지만, `t[0] = 999` 처럼 **수정은 불가능**합니다. 시도하면 `TypeError` 가 발생합니다.
#
# **🎯 Task**:
# 1. `loc = (37.56, 126.97)` 에서 위도(첫번째)와 경도(두번째)를 각각 `lat`, `lng` 에 저장하세요.
# 2. `try/except` 블록 안에서 `loc[0] = 0.0` 을 시도하고, 발생하는 예외의 이름을 `error_name` 에 저장하세요.
#
# **Expected Output**:
# ```
# 위도: 37.56, 경도: 126.97
# 발생한 예외: TypeError
# ```
#
# **💡 Hint**: `except TypeError as e:` 처럼 쓰면 `type(e).__name__` 으로 이름을 얻을 수 있습니다.

# %%
loc = (37.56, 126.97)

# TODO 1: 인덱싱으로 위도/경도 추출
lat = # ____
lng = # ____
print(f"위도: {lat}, 경도: {lng}")

# TODO 2: 수정 시도 → 예외 잡기
error_name = None
try:
    # ____   # loc[0] 에 0.0 을 대입 시도
    pass
except # ____ as e:
    error_name = # ____

print("발생한 예외:", error_name)

# %% [markdown]
# ### 3.3 튜플의 패킹(packing)과 언패킹(unpacking)
#
# **개념**:
# - **패킹**: 여러 값을 하나의 튜플로 묶는 것 → `t = 10, 20, 30`
# - **언패킹**: 튜플을 풀어 여러 변수에 나누어 담는 것 → `a, b, c = t`
#
# **예시**:
# ```python
# point = 3, 4           # 패킹
# x, y = point           # 언패킹
# ```
#
# **🎯 Task**: 학생 정보 `student = ('홍길동', 22, '컴공')` 이 있습니다.
# 언패킹을 이용하여 이름, 나이, 전공을 `name`, `age`, `major` 에 한 줄로 담으세요.
#
# **Expected Output**:
# ```
# 이름=홍길동, 나이=22, 전공=컴공
# ```

# %%
student = ('홍길동', 22, '컴공')

# TODO: 한 줄로 언패킹하세요
# ____ = student

print(f"이름={name}, 나이={age}, 전공={major}")

# %% [markdown]
# ### 3.4 튜플을 이용한 스왑(swap)
#
# **개념**: `a, b = b, a` 한 줄이면 두 변수의 값을 교환할 수 있습니다. 임시 변수가 필요 없습니다.
#
# **🎯 Task**: `x = 100`, `y = 200` 을 한 줄의 튜플 스왑으로 교환하세요.
#
# **Expected Output**:
# ```
# 교환 전: x=100, y=200
# 교환 후: x=200, y=100
# ```

# %%
x = 100
y = 200
print(f"교환 전: x={x}, y={y}")

# TODO: 튜플 스왑으로 x 와 y 의 값을 교환
# ____

print(f"교환 후: x={x}, y={y}")

# %% [markdown]
# ### 3.5 튜플의 연산 — `+`, `*`, 그리고 `(x,)` 함정
#
# **개념**:
# - `+` : 두 튜플을 연결
# - `*` : 반복
# - ⚠️ 튜플 + 정수는 **불가능**. 원소 1개짜리 튜플은 반드시 `(x,)` 로 써야 합니다.
#
# **예시**:
# ```python
# (1, 2) + (3, 4)   # (1, 2, 3, 4)
# ('ha',) * 3       # ('ha', 'ha', 'ha')
# ```
#
# **🎯 Task**:
# 1. `t = (1, 2, 3)` 에 원소 `4` 를 튜플 연결로 **추가**한 결과를 `t_added` 에 저장
# 2. `('hi',)` 를 4번 반복한 결과를 `t_repeat` 에 저장
#
# **Expected Output**:
# ```
# t_added = (1, 2, 3, 4)
# t_repeat = ('hi', 'hi', 'hi', 'hi')
# ```
#
# **💡 Hint**: `4` 를 그냥 더하면 에러입니다. `(4,)` 로 만들어서 더해야 합니다.

# %%
t = (1, 2, 3)

# TODO 1: (1, 2, 3) 뒤에 4 를 원소로 추가
t_added = # ____

# TODO 2: ('hi',) 를 4번 반복
t_repeat = # ____

print("t_added =", t_added)
print("t_repeat =", t_repeat)

# %% [markdown]
# ### 3.6 튜플 수정하고 싶다면? `list()` ↔ `tuple()` 변환
#
# **개념**: 튜플은 직접 수정할 수 없으니, **리스트로 변환 → 수정 → 다시 튜플로 변환** 패턴을 씁니다.
#
# **🎯 Task**: `colors = ('red', 'green', 'blue')` 의 두 번째 원소를 `'yellow'` 로 바꾼 결과를 튜플 `new_colors` 로 만드세요.
#
# **Expected Output**:
# ```
# ('red', 'yellow', 'blue')
# ```

# %%
colors = ('red', 'green', 'blue')

# TODO: 리스트로 변환 → 수정 → 다시 튜플로
temp = # ____             # colors 를 리스트로
# ____                    # 인덱스 1 의 값을 'yellow' 로 변경
new_colors = # ____       # 리스트를 다시 튜플로

print(new_colors)

# %% [markdown]
# ### 3.7 함수에서 여러 값을 튜플로 반환하기
#
# **개념**: `return a, b` 처럼 쉼표로 나열하면 파이썬은 자동으로 튜플로 묶어 반환합니다. 호출 쪽에서는 **언패킹**으로 받습니다.
#
# **상황**: 원화(KRW)를 받아 **달러(USD)와 유로(EUR)로 환산**한 결과를 동시에 돌려주는 함수.
# - 1 USD = 1350 KRW
# - 1 EUR = 1450 KRW
#
# **🎯 Task**: 함수 `convert_currency(krw)` 를 완성하세요. `(usd, eur)` 튜플을 반환해야 합니다.
#
# **Expected Output**:
# ```
# USD: 2.22, EUR: 2.07
# 반환 타입: <class 'tuple'>
# ```
#
# **💡 Hint**: `usd = krw / 1350` 을 소수점 둘째 자리까지 반올림하려면 `round(usd, 2)` 를 씁니다.

# %%
def convert_currency(krw):
    # TODO: usd 와 eur 를 계산해 둘 다 반환하세요 (소수점 둘째 자리까지 round)
    usd = # ____
    eur = # ____
    return # ____

# 호출 & 언패킹
result = convert_currency(3000)
u, e = # ____    # result 를 u, e 로 언패킹

print(f"USD: {u}, EUR: {e}")
print(f"반환 타입: {type(result)}")

# %% [markdown]
# ---
# ## 📘 Section 4. 집합 자료형 (Set)
#
# 집합은 **순서가 없고, 중복을 허용하지 않는** 자료형입니다. 수학의 집합과 같은 연산(합/교/차/대칭차)을 할 수 있습니다.

# %% [markdown]
# ### 4.1 집합 생성하기
#
# **개념**:
# - `{1, 2, 3}` : 중괄호로 직접 생성
# - `set([1, 2, 2, 3])` : 리스트/튜플에서 생성 (중복 제거됨)
# - ⚠️ **빈 집합은 `{}` 가 아니라 `set()`** 입니다. (`{}` 는 빈 딕셔너리)
#
# **🎯 Task**:
# 1. `s1` : `{'사과', '바나나', '포도'}` 를 직접 생성
# 2. `s2` : 리스트 `['개', '고양이', '개', '토끼', '고양이']` 를 `set()` 으로 변환
#
# **Expected Output** (순서는 다를 수 있음):
# ```
# s1 = {'사과', '바나나', '포도'}       (원소 3개)
# s2 = {'개', '고양이', '토끼'}         (원소 3개)
# ```

# %%
# TODO:
s1 = # ____
s2 = # ____

print(f"s1 = {s1}       (원소 {len(s1)}개)")
print(f"s2 = {s2}       (원소 {len(s2)}개)")

# %% [markdown]
# ### 4.2 집합의 특징 확인 — 중복 제거, 순서 없음, 인덱스 불가
#
# **🎯 Task**:
# 1. 숫자 리스트 `[5, 1, 2, 1, 5, 3, 2]` 를 집합으로 바꾼 것을 `uniq` 에 저장
# 2. `uniq` 의 원소 개수를 `n` 에 저장
# 3. `5 in uniq` 의 결과를 `has_five` 에 저장
#
# **Expected Output**:
# ```
# uniq 원소 개수: 4
# 5 in uniq? True
# ```

# %%
nums = [5, 1, 2, 1, 5, 3, 2]

# TODO:
uniq = # ____
n = # ____
has_five = # ____

print("uniq 원소 개수:", n)
print("5 in uniq?", has_five)

# %% [markdown]
# ### 4.3 합집합 — `|` 또는 `union()`
#
# **개념**: 두 집합의 모든 원소를 모은 집합.
#
# **상황**: 두 친구가 좋아하는 영화 장르.
# - `minji` = `{'액션', '코미디', '로맨스'}`
# - `junho` = `{'로맨스', 'SF', '공포'}`
#
# **🎯 Task**: 두 사람이 좋아하는 **모든** 장르의 합집합 `all_genres` 를 **`|` 연산자**로 구하세요.
#
# **Expected Output** (순서는 다를 수 있음):
# ```
# {'액션', '코미디', '로맨스', 'SF', '공포'}
# ```

# %%
minji = {'액션', '코미디', '로맨스'}
junho = {'로맨스', 'SF', '공포'}

# TODO:
all_genres = # ____

print(all_genres)

# %% [markdown]
# ### 4.4 교집합 — `&` 또는 `intersection()`
#
# **개념**: 두 집합에 **모두** 있는 원소만 모은 집합.
#
# **🎯 Task**: `minji` 와 `junho` 가 **공통으로** 좋아하는 장르 `common` 을 **`intersection()` 메소드**로 구하세요.
#
# **Expected Output**:
# ```
# {'로맨스'}
# ```

# %%
minji = {'액션', '코미디', '로맨스'}
junho = {'로맨스', 'SF', '공포'}

# TODO: intersection() 메소드 사용
common = # ____

print(common)

# %% [markdown]
# ### 4.5 차집합 — `-` 또는 `difference()`
#
# **개념**: 첫 번째 집합에만 있고, 두 번째 집합에는 없는 원소들.
#
# **🎯 Task**: **민지만** 좋아하는 장르 `only_minji` 를 **`-` 연산자**로 구하세요.
#
# **Expected Output** (순서는 다를 수 있음):
# ```
# {'액션', '코미디'}
# ```

# %%
minji = {'액션', '코미디', '로맨스'}
junho = {'로맨스', 'SF', '공포'}

# TODO:
only_minji = # ____

print(only_minji)

# %% [markdown]
# ### 4.6 대칭 차집합 — `^` 또는 `symmetric_difference()`
#
# **개념**: **둘 중 한 쪽에만** 있는 원소들. (= 합집합 - 교집합)
#
# **🎯 Task**: 두 사람 중 한 명만 좋아하는 장르 `exclusive` 를 **`^` 연산자**로 구하세요.
#
# **Expected Output** (순서는 다를 수 있음):
# ```
# {'액션', '코미디', 'SF', '공포'}
# ```

# %%
minji = {'액션', '코미디', '로맨스'}
junho = {'로맨스', 'SF', '공포'}

# TODO:
exclusive = # ____

print(exclusive)

# %% [markdown]
# ### 4.7 여러 집합의 연속 연산
#
# **상황**: 세 명의 친구가 좋아하는 장르.
# - `a = {'액션', '코미디', '로맨스'}`
# - `b = {'로맨스', 'SF', '공포'}`
# - `c = {'로맨스', '코미디', '다큐'}`
#
# **🎯 Task**:
# 1. **셋 모두가** 좋아하는 장르 `all_common` (교집합 연속)
# 2. 세 명 중 **누구라도** 좋아하는 장르 `any_liked` (합집합 연속)
#
# **Expected Output**:
# ```
# all_common = {'로맨스'}
# any_liked 개수 = 6
# ```

# %%
a = {'액션', '코미디', '로맨스'}
b = {'로맨스', 'SF', '공포'}
c = {'로맨스', '코미디', '다큐'}

# TODO: a, b, c 모두의 교집합
all_common = # ____

# TODO: a, b, c 모두의 합집합
any_liked = # ____

print("all_common =", all_common)
print("any_liked 개수 =", len(any_liked))

# %% [markdown]
# ---
# ## 📘 Section 5. 반복가능(Iterable) 자료형과 `zip()` 함수
#
# **반복가능(iterable) 자료형**이란 `for ... in` 으로 하나씩 꺼내어 반복할 수 있는 자료형을 말합니다. 리스트, 튜플, 집합, 딕셔너리, 문자열이 모두 이에 해당합니다.
#
# `zip()` 함수는 **여러 반복가능 자료형을 서로 짝지어 묶어주는 함수**입니다.

# %% [markdown]
# ### 5.1 반복가능이란? `for` 로 하나씩 꺼내보기
#
# **🎯 Task**: 리스트, 튜플, 문자열, 집합 각각에 대해 `for` 로 원소를 하나씩 출력하세요.
#
# **Expected Output** (집합 부분은 순서가 다를 수 있음):
# ```
# -- list --
# red
# green
# blue
# -- tuple --
# 1
# 2
# 3
# -- string --
# P
# y
# -- set --
# A
# ```

# %%
my_list = ['red', 'green', 'blue']
my_tuple = (1, 2, 3)
my_str = 'Py'
my_set = {'A'}

# TODO: 각각을 for 로 순회해 원소를 출력
print('-- list --')
for # ____ in # ____:
    print(item)

print('-- tuple --')
for # ____ in # ____:
    print(item)

print('-- string --')
for # ____ in # ____:
    print(item)

print('-- set --')
for # ____ in # ____:
    print(item)

# %% [markdown]
# ### 5.2 `zip()` 기본 — 두 개 묶기
#
# **개념**: `zip(a, b)` 는 `a` 와 `b` 의 같은 위치 원소들끼리 튜플로 묶어줍니다.
# 결과는 **반복자(iterator)** 이므로, 확인하려면 `list()` 로 변환해야 합니다.
#
# **예시**:
# ```python
# list(zip([1, 2], ['a', 'b']))
# # [(1, 'a'), (2, 'b')]
# ```
#
# **🎯 Task**: 동호회 회원 이름과 나이를 짝지으세요.
# - `names = ['유진', '서준', '하윤']`
# - `ages = [24, 29, 21]`
#
# **Expected Output**:
# ```
# [('유진', 24), ('서준', 29), ('하윤', 21)]
# ```

# %%
names = ['유진', '서준', '하윤']
ages = [24, 29, 21]

# TODO: zip 결과를 list 로 변환하세요
paired = # ____

print(paired)

# %% [markdown]
# ### 5.3 `zip()` 은 반복자다 — 한 번 소진되면 끝
#
# **개념**: `zip()` 결과는 한 번 순회하면 비워집니다. 다시 쓰려면 `list()` 로 저장해두세요.
#
# **🎯 Task**:
# 1. `z = zip(names, ages)` 생성
# 2. `first_pass` : `list(z)` 결과
# 3. `second_pass` : 다시 `list(z)` 결과 — 무엇이 나올까요?
#
# **Expected Output**:
# ```
# first_pass = [('유진', 24), ('서준', 29), ('하윤', 21)]
# second_pass = []
# ```

# %%
names = ['유진', '서준', '하윤']
ages = [24, 29, 21]

# TODO:
z = # ____
first_pass = # ____
second_pass = # ____

print("first_pass =", first_pass)
print("second_pass =", second_pass)

# %% [markdown]
# ### 5.4 세 개 이상 묶기
#
# **🎯 Task**: 이름, 나이, 지역 세 리스트를 한 번에 묶으세요.
# - `names = ['유진', '서준', '하윤']`
# - `ages = [24, 29, 21]`
# - `cities = ['부산', '대구', '광주']`
#
# **Expected Output**:
# ```
# [('유진', 24, '부산'), ('서준', 29, '대구'), ('하윤', 21, '광주')]
# ```

# %%
names = ['유진', '서준', '하윤']
ages = [24, 29, 21]
cities = ['부산', '대구', '광주']

# TODO:
triples = # ____

print(triples)

# %% [markdown]
# ### 5.5 `zip(*zipped)` — 언집(unzip)
#
# **개념**: `*` 연산자를 zip 결과 앞에 붙이면 **다시 풀어낼 수 있습니다**.
#
# **예시**:
# ```python
# pairs = [(1, 'a'), (2, 'b'), (3, 'c')]
# nums, letters = zip(*pairs)
# # nums = (1, 2, 3),  letters = ('a', 'b', 'c')
# ```
#
# **🎯 Task**: 아래 `pairs` 를 언집하여 `numbers` 와 `labels` 로 나누세요.
#
# **Expected Output**:
# ```
# numbers = (10, 20, 30)
# labels = ('X', 'Y', 'Z')
# ```

# %%
pairs = [(10, 'X'), (20, 'Y'), (30, 'Z')]

# TODO: zip 과 * 를 사용
numbers, labels = # ____

print("numbers =", numbers)
print("labels =", labels)

# %% [markdown]
# ### 5.6 실전 응용 — `dict(zip(...))` 으로 딕셔너리 한 번에 만들기
#
# **개념**: 두 리스트를 짝지어 바로 딕셔너리로 변환하는 대표적인 관용구입니다.
#
# **🎯 Task**: `names` 를 키로, `ages` 를 값으로 하는 딕셔너리 `member_age` 를 **한 줄로** 만드세요.
#
# **Expected Output**:
# ```
# {'유진': 24, '서준': 29, '하윤': 21}
# ```

# %%
names = ['유진', '서준', '하윤']
ages = [24, 29, 21]

# TODO: 한 줄로 작성
member_age = # ____

print(member_age)

# %% [markdown]
# ---
# ## 📘 Section 6. 튜플과 문자열 슬라이싱
#
# 리스트에서 쓰던 슬라이싱 `[start:stop:step]` 은 **튜플과 문자열에서도 똑같이** 동작합니다.

# %% [markdown]
# ### 6.1 기본 슬라이싱 `[start:stop]`
#
# **개념**: `start` 번째(포함) ~ `stop` 번째(제외) 원소를 잘라냅니다.
#
# **🎯 Task**: 태양계 행성 튜플에서 **앞에서 4개** 를 잘라 `inner` 에 저장하세요.
#
# **Expected Output**:
# ```
# ('수성', '금성', '지구', '화성')
# ```

# %%
planets = ('수성', '금성', '지구', '화성', '목성', '토성', '천왕성', '해왕성')

# TODO:
inner = # ____

print(inner)

# %% [markdown]
# ### 6.2 스텝 `[start:stop:step]`
#
# **개념**: 세 번째 값은 간격(step)입니다. 기본값은 1입니다.
#
# **🎯 Task**: `planets` 에서 **짝수 인덱스(0,2,4,6)**의 행성만 뽑아 `even_idx` 에 저장하세요.
#
# **Expected Output**:
# ```
# ('수성', '지구', '목성', '천왕성')
# ```
#
# **💡 Hint**: `[::2]` 처럼 start/stop 을 비워두면 각각 처음/끝을 의미합니다.

# %%
planets = ('수성', '금성', '지구', '화성', '목성', '토성', '천왕성', '해왕성')

# TODO:
even_idx = # ____

print(even_idx)

# %% [markdown]
# ### 6.3 음수 인덱스와 음수 스텝
#
# **개념**:
# - 음수 인덱스: 뒤에서부터 (`-1` 이 마지막 원소)
# - 음수 스텝: 뒤에서 앞으로 (역순)
#
# **🎯 Task**:
# 1. `last3` : 마지막 3개의 행성
# 2. `reversed_planets` : 전체를 역순으로
#
# **Expected Output**:
# ```
# last3 = ('토성', '천왕성', '해왕성')
# reversed_planets = ('해왕성', '천왕성', '토성', '목성', '화성', '지구', '금성', '수성')
# ```

# %%
planets = ('수성', '금성', '지구', '화성', '목성', '토성', '천왕성', '해왕성')

# TODO:
last3 = # ____                # 음수 인덱스 활용
reversed_planets = # ____     # [::-1] 활용

print("last3 =", last3)
print("reversed_planets =", reversed_planets)

# %% [markdown]
# ### 6.4 문자열 슬라이싱
#
# **개념**: 문자열도 튜플처럼 인덱싱과 슬라이싱이 가능합니다.
#
# **🎯 Task**: `s = 'Python_Programming'` 에서 아래를 구하세요.
# 1. `first6` : 앞 6글자
# 2. `after7` : 8번째 글자부터 끝까지 (`P` 가 시작)
# 3. `backwards` : 전체 문자열을 뒤집은 것
#
# **Expected Output**:
# ```
# first6 = Python
# after7 = Programming
# backwards = gnimmargorP_nohtyP
# ```
#
# **💡 Hint**: 8번째 글자의 **인덱스**는 7 입니다 (0부터 세기 때문).

# %%
s = 'Python_Programming'

# TODO:
first6 = # ____
after7 = # ____
backwards = # ____

print("first6 =", first6)
print("after7 =", after7)
print("backwards =", backwards)

# %% [markdown]
# ---
# ## 🏆 Section 7. 종합 미니 프로젝트 (Capstone)
#
# ### 📋 시나리오: 수강신청 관리 시스템
#
# 지금까지 배운 **딕셔너리 + 튜플 + 집합 + `zip()`** 을 모두 사용하여, 간단한 수강신청 관리 프로그램을 만들어봅시다.
#
# **주어진 데이터**:
# - 학번 리스트: `['2401', '2402', '2403', '2404', '2405']`
# - 점수 리스트: `[88, 72, 95, 54, 78]`
# - A반이 수강신청한 학번 집합: `{'2401', '2402', '2404'}`
# - B반이 수강신청한 학번 집합: `{'2402', '2403', '2405'}`

# %% [markdown]
# ### 7.1 학번과 점수를 딕셔너리로 묶기
#
# **🎯 Task**: `zip()` 과 `dict()` 를 사용하여 학번을 키로, 점수를 값으로 하는 딕셔너리 `scores` 를 만드세요.
#
# **Expected Output**:
# ```
# {'2401': 88, '2402': 72, '2403': 95, '2404': 54, '2405': 78}
# ```

# %%
ids = ['2401', '2402', '2403', '2404', '2405']
points = [88, 72, 95, 54, 78]

# TODO: dict(zip(...)) 관용구 사용
scores = # ____

print(scores)

# %% [markdown]
# ### 7.2 최고점과 최저점을 함수로 구해 튜플로 반환
#
# **🎯 Task**: `scores` 딕셔너리를 받아 **(최고점 학번, 최저점 학번)** 튜플을 반환하는 함수 `find_top_bottom(scores)` 을 완성하세요.
#
# **Expected Output**:
# ```
# 최고점 학번: 2403, 최저점 학번: 2404
# ```
#
# **💡 Hint**: `max(scores, key=scores.get)` 는 값이 가장 큰 키를 돌려줍니다.

# %%
def find_top_bottom(scores):
    # TODO: top_id, bottom_id 를 구해 튜플로 반환하세요
    top_id = # ____      # 값이 가장 큰 키
    bottom_id = # ____   # 값이 가장 작은 키
    return # ____

scores = {'2401': 88, '2402': 72, '2403': 95, '2404': 54, '2405': 78}
top, bottom = # ____   # 함수 호출 결과를 언패킹

print(f"최고점 학번: {top}, 최저점 학번: {bottom}")

# %% [markdown]
# ### 7.3 집합 연산으로 학생 분류하기
#
# **🎯 Task**: A반 과 B반 수강신청 정보를 이용해 다음을 구하세요.
# - `both` : **두 반 모두** 수강신청한 학생 (교집합)
# - `only_a` : **A반만** 수강신청한 학생 (차집합)
# - `any_class` : **어느 반이든** 수강신청한 학생 (합집합)
# - `one_only` : **딱 한 반만** 수강신청한 학생 (대칭 차집합)
#
# **Expected Output** (순서는 다를 수 있음):
# ```
# both = {'2402'}
# only_a = {'2401', '2404'}
# any_class = {'2401', '2402', '2403', '2404', '2405'}
# one_only = {'2401', '2403', '2404', '2405'}
# ```

# %%
class_a = {'2401', '2402', '2404'}
class_b = {'2402', '2403', '2405'}

# TODO: 네 가지 집합 연산
both = # ____
only_a = # ____
any_class = # ____
one_only = # ____

print("both =", both)
print("only_a =", only_a)
print("any_class =", any_class)
print("one_only =", one_only)

# %% [markdown]
# ### 7.4 최종 리포트
#
# **🎯 Task**: 지금까지 만든 변수들을 조합하여, `any_class` 에 포함된 각 학생의 **학번과 점수**를 한 줄씩 출력하는 코드를 완성하세요. 단, **학번 오름차순**으로 출력합니다.
#
# **Expected Output**:
# ```
# 2401: 88점
# 2402: 72점
# 2403: 95점
# 2404: 54점
# 2405: 78점
# ```
#
# **💡 Hint**: `sorted(any_class)` 는 정렬된 리스트를 돌려줍니다. 점수는 `scores[학번]` 으로 가져올 수 있습니다.

# %%
scores = {'2401': 88, '2402': 72, '2403': 95, '2404': 54, '2405': 78}
class_a = {'2401', '2402', '2404'}
class_b = {'2402', '2403', '2405'}
any_class = class_a | class_b

# TODO: 정렬된 학번을 순회하며 점수와 함께 출력
for # ____ in sorted(# ____):
    print(f"{sid}: {# ____}점")

# %% [markdown]
# ---
# ## 🎉 수고하셨습니다!
#
# 모든 셀이 에러 없이 실행되고, Expected Output과 동일한 결과가 나왔다면 7장 실습을 성공적으로 완료한 것입니다.
#
# ### 다음 단계 제안
# - 수강신청 시스템에 **새로운 반(class_c)** 을 추가해 보세요.
# - `scores` 에서 **평균 이상의 학생만** 골라내는 기능을 추가해 보세요.
# - `zip()` 으로 **세 개 이상의 리스트**(학번, 이름, 점수)를 한 번에 묶어 보세요.
