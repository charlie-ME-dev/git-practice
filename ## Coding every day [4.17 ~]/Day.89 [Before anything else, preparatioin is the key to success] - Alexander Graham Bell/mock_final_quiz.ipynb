# %% [markdown]
# # 🐍 파이썬 기말 모의고사 / Python Final Mock Exam
#
# > **형식 / Format:** 출력 예측 + 버그 찾기 · **만점 / Total:** 100점 · **권장 시간 / Suggested time:** 60분
#
# 안녕하세요 여러분! 이번 학기에 배운 내용을 점검하는 모의고사입니다. 새로운 일상 상황(학식 카드, 도서관, 교통카드, 기숙사 생활)으로 문제를 냈으니, 외운 답이 아니라 **원리를 적용**하는 연습을 해보세요.
# *Hi everyone! This mock exam checks what you learned this semester. The scenarios are fresh everyday situations (meal cards, the library, transit cards, dorm life) so you practice **applying the logic**, not recalling memorized answers.*
#
# **범위 / Coverage:** 문자열·리스트·딕셔너리·튜플·세트, 제어 흐름, 함수 (집중) / OOP·예외 처리 (가볍게)
# *Strings, lists, dicts, tuples, sets, control flow, functions (heavy) / OOP & exceptions (light).*
#
# ---
# ### 📝 푸는 방법 / How to take it
# 1. **Part 1 (출력 예측):** 코드를 보고 출력 결과를 **먼저 머릿속이나 종이에 예측**하세요. 그 다음 셀을 실행해서 맞는지 확인합니다.
#    *Predict the output in your head or on paper **first**, then run the cell to check.*
# 2. **Part 2 (버그 찾기):** 코드에는 버그가 하나씩 있습니다. (1) 무엇이 잘못됐는지 한 문장으로 설명하고 (2) 직접 고쳐서 실행하세요.
#    *Each snippet has one bug. (1) Explain in one sentence what's wrong, then (2) fix it and run.*
# 3. 모든 셀은 **독립적으로** 작성되어 있어 어떤 순서로 실행해도 됩니다.
#    *Every cell is **self-contained** — run them in any order.*
#
# > 💡 함수·변수 이름은 항상 **snake_case**입니다. 클래스만 PascalCase예요.
# > *Function and variable names are always snake_case; only classes use PascalCase.*

# %% [markdown]
# ---
# ## Part 1 · 출력 예측 / Predict the Output
# **20문항 × 3점 = 60점 / 20 questions × 3 pts = 60 pts**
#
# 각 셀의 출력을 **먼저 예측**한 뒤 실행해서 확인하세요.
# *Predict each cell's output **first**, then run it to check.*

# %% [markdown]
# **Q1. 문자열 — 도서관 청구기호 정리 / Strings — cleaning a library call number** &nbsp;&nbsp;`(3점 / pts)`
#
# ✍️ 예상 출력 / Predicted output: ________________

# %%
code = "  KR-2024-Fiction  "
clean = code.strip().lower()
print(clean.replace("-", "/"))

# %% [markdown]
# **Q2. 문자열 — 노선 정류장 분리 / Strings — splitting a transit route** &nbsp;&nbsp;`(3점 / pts)`
#
# ✍️ 예상 출력 / Predicted output: ________________

# %%
route = "Station1>Station2>Station3"
stops = route.split(">")
print(len(stops), stops[-1])

# %% [markdown]
# **Q3. 문자열 — 슬라이싱과 대소문자 / Strings — slicing and case** &nbsp;&nbsp;`(3점 / pts)`
#
# ✍️ 예상 출력 / Predicted output: ________________

# %%
name = "cafeteria"
print(name[:4].upper() + name[4:])

# %% [markdown]
# **Q4. 리스트 — 기숙사 청소 당번 / Lists — dorm chore list** &nbsp;&nbsp;`(3점 / pts)`
#
# ✍️ 예상 출력 / Predicted output: ________________

# %%
chores = ["dishes", "trash", "vacuum", "laundry"]
chores.insert(1, "dusting")
chores.pop()
print(chores)

# %% [markdown]
# **Q5. 리스트 — 정렬 / Lists — sorting** &nbsp;&nbsp;`(3점 / pts)`
#
# ✍️ 예상 출력 / Predicted output: ________________

# %%
scores = [88, 72, 95, 60]
scores.sort(reverse=True)
print(scores[1])

# %% [markdown]
# **Q6. 리스트 — 컴프리헨션 필터 / Lists — comprehension filter (meal-card balances)** &nbsp;&nbsp;`(3점 / pts)`
#
# ✍️ 예상 출력 / Predicted output: ________________

# %%
balances = [10000, 5000, 0, 15000, 0]
nonzero = [b for b in balances if b > 0]
print(nonzero)

# %% [markdown]
# **Q7. 딕셔너리 — get과 기본값 / Dicts — get with default** &nbsp;&nbsp;`(3점 / pts)`
#
# ✍️ 예상 출력 / Predicted output: ________________

# %%
inventory = {"python": 3, "java": 1}
print(inventory.get("python", 0) + inventory.get("c++", 0))

# %% [markdown]
# **Q8. 딕셔너리 — items 반복 / Dicts — looping items (weekly transit taps)** &nbsp;&nbsp;`(3점 / pts)`
#
# ✍️ 예상 출력 / Predicted output: ________________

# %%
taps = {"Mon": 2, "Tue": 4, "Wed": 1}
total = 0
for day, count in taps.items():
    total += count
print(total)

# %% [markdown]
# **Q9. 딕셔너리 — 키 덮어쓰기와 추가 / Dicts — overwrite and add a key (cafeteria menu)** &nbsp;&nbsp;`(3점 / pts)`
#
# ✍️ 예상 출력 / Predicted output: ________________

# %%
menu = {"rice": 3000, "soup": 2000}
menu["rice"] = 3500
menu["salad"] = 4000
print(len(menu), menu["rice"])

# %% [markdown]
# **Q10. 튜플 — 언패킹 / Tuples — unpacking (dorm room code)** &nbsp;&nbsp;`(3점 / pts)`
#
# ✍️ 예상 출력 / Predicted output: ________________

# %%
room = ("A", 304, 2)
building, number, capacity = room
print(f"{building}{number}-{capacity}")

# %% [markdown]
# **Q11. 튜플 — count와 index / Tuples — count and index** &nbsp;&nbsp;`(3점 / pts)`
#
# ✍️ 예상 출력 / Predicted output: ________________

# %%
record = (1, 2, 2, 3, 2)
print(record.count(2), record.index(3))

# %% [markdown]
# **Q12. 세트 — 교집합 / Sets — intersection (library tags)** &nbsp;&nbsp;`(3점 / pts)`
#
# ✍️ 예상 출력 / Predicted output: ________________

# %%
fiction = {"novel", "drama", "poetry"}
borrowed = {"poetry", "manual", "novel"}
print(len(fiction & borrowed))

# %% [markdown]
# **Q13. 세트 — 중복 제거 / Sets — deduplication (tap-in card IDs)** &nbsp;&nbsp;`(3점 / pts)`
#
# ✍️ 예상 출력 / Predicted output: ________________

# %%
cards = [101, 102, 101, 103, 102, 101]
unique = set(cards)
print(len(unique))

# %% [markdown]
# **Q14. 제어 흐름 — 중첩 반복문 / Control flow — nested loops** &nbsp;&nbsp;`(3점 / pts)`
#
# ✍️ 예상 출력 / Predicted output: ________________

# %%
total = 0
for i in range(1, 4):
    for j in range(i):
        total += 1
print(total)

# %% [markdown]
# **Q15. 제어 흐름 — while와 차감 / Control flow — while loop (meal-card spending)** &nbsp;&nbsp;`(3점 / pts)`
#
# ✍️ 예상 출력 / Predicted output: ________________

# %%
balance = 10000
meals = 0
while balance >= 3000:
    balance -= 3000
    meals += 1
print(meals, balance)

# %% [markdown]
# **Q16. 제어 흐름 — elif 사슬 / Control flow — elif chain (library late fine)** &nbsp;&nbsp;`(3점 / pts)`
#
# ✍️ 예상 출력 / Predicted output: ________________

# %%
days_late = 5
if days_late == 0:
    fine = 0
elif days_late <= 3:
    fine = 500
elif days_late <= 7:
    fine = 1000
else:
    fine = 2000
print(fine)

# %% [markdown]
# **Q17. 함수 — 기본 매개변수 / Functions — default parameters (dorm cost)** &nbsp;&nbsp;`(3점 / pts)`
#
# ✍️ 예상 출력 / Predicted output: ________________

# %%
def room_cost(base, nights=1, breakfast=False):
    cost = base * nights
    if breakfast:
        cost += 2000 * nights
    return cost

print(room_cost(10000, 2))

# %% [markdown]
# **Q18. 함수 — *args / Functions — *args (cafeteria order)** &nbsp;&nbsp;`(3점 / pts)`
#
# ✍️ 예상 출력 / Predicted output: ________________

# %%
def total_order(*prices):
    return sum(prices)

print(total_order(3000, 2000, 1500))

# %% [markdown]
# **Q19. 함수 — 다중 반환값 / Functions — multiple return values (trip summary)** &nbsp;&nbsp;`(3점 / pts)`
#
# ✍️ 예상 출력 / Predicted output: ________________

# %%
def trip_summary(distances):
    return len(distances), sum(distances)

count, dist = trip_summary([3, 5, 2])
print(count, dist)

# %% [markdown]
# **Q20. 함수 — 가변 객체와 None 반환 / Functions — mutation vs. None return (loyalty stamps)** &nbsp;&nbsp;`(3점 / pts)`
#
# ✍️ 예상 출력 / Predicted output: ________________

# %%
def add_stamp(card):
    card["stamps"] += 1

loyalty = {"stamps": 4}
result = add_stamp(loyalty)
print(result, loyalty["stamps"])

# %% [markdown]
# ---
# ## Part 2 · 버그 찾기 / Find & Fix the Bug
# **8문항 × 5점 = 40점 / 8 questions × 5 pts = 40 pts**
# *(버그 설명 2점 + 올바른 수정 3점 / 2 pts to identify + 3 pts to fix)*
#
# 각 코드에는 버그가 **하나** 있습니다. 먼저 실행해서 어떤 일이 벌어지는지 보고, 무엇이 잘못됐는지 적은 뒤 **셀 안에서 직접 고쳐** 다시 실행하세요.
# *Each snippet has **one** bug. Run it to see what happens, write what's wrong, then **fix it in the cell** and re-run.*

# %% [markdown]
# **B1. 버그 찾기 — 이름 서식 / Find the bug — formatting names** &nbsp;&nbsp;`(5점 / pts)`
#
# 🎯 의도: 각 이름을 Title Case로 바꿔 반환
# *Intent: return each name in Title Case*
#
# 🐞 버그 / Bug: ________________________________________
# 🔧 수정 방법 / Fix: ____________________________________

# %%
def format_names(raw):
    names = raw.split(",")
    for name in names:
        name = name.title()
    return names

print(format_names("kim minji,lee junho"))
# 기대 / Expected: ['Kim Minji', 'Lee Junho']

# %% [markdown]
# **B2. 버그 찾기 — 장르 세기 / Find the bug — counting genres** &nbsp;&nbsp;`(5점 / pts)`
#
# 🎯 의도: 각 장르가 몇 번 대출됐는지 세기
# *Intent: count how many times each genre was borrowed*
#
# 🐞 버그 / Bug: ________________________________________
# 🔧 수정 방법 / Fix: ____________________________________

# %%
def count_genres(genres):
    counts = {}
    for g in genres:
        counts[g] += 1
    return counts

print(count_genres(["fiction", "fiction", "poetry"]))
# 기대 / Expected: {'fiction': 2, 'poetry': 1}

# %% [markdown]
# **B3. 버그 찾기 — 고유 방문자 / Find the bug — unique visitors** &nbsp;&nbsp;`(5점 / pts)`
#
# 🎯 의도: 고유한 [카드, 게이트] 쌍의 개수 반환
# *Intent: return the number of unique [card, gate] pairs*
#
# 🐞 버그 / Bug: ________________________________________
# 🔧 수정 방법 / Fix: ____________________________________

# %%
def unique_visitors(log):
    seen = set()
    for entry in log:
        seen.add(entry)
    return len(seen)

print(unique_visitors([[1, 2], [1, 2], [3]]))
# 기대 / Expected: 2

# %% [markdown]
# **B4. 버그 찾기 — 식비 합계 / Find the bug — total spent** &nbsp;&nbsp;`(5점 / pts)`
#
# 🎯 의도: 모든 가격을 더하기
# *Intent: add up every price*
#
# 🐞 버그 / Bug: ________________________________________
# 🔧 수정 방법 / Fix: ____________________________________

# %%
def total_spent(prices):
    total = 0
    for i in range(len(prices) - 1):
        total += prices[i]
    return total

print(total_spent([3000, 2000, 1500]))
# 기대 / Expected: 6500

# %% [markdown]
# **B5. 버그 찾기 — 짐 싸기 목록 / Find the bug — packing list** &nbsp;&nbsp;`(5점 / pts)`
#
# 🎯 의도: 호출할 때마다 새 가방에 물건 하나만 담기
# *Intent: each call starts a fresh bag with just that item*
#
# 🐞 버그 / Bug: ________________________________________
# 🔧 수정 방법 / Fix: ____________________________________

# %%
def add_item(item, bag=[]):
    bag.append(item)
    return bag

print(add_item("pillow"))
print(add_item("blanket"))
# 기대 / Expected: ['pillow'] 그리고 / then ['blanket']

# %% [markdown]
# **B6. 버그 찾기 — 연체 도서 확인 / Find the bug — overdue check** &nbsp;&nbsp;`(5점 / pts)`
#
# 🎯 의도: 14일 넘게 연체된 책이 하나라도 있으면 True
# *Intent: True if ANY book is more than 14 days overdue*
#
# 🐞 버그 / Bug: ________________________________________
# 🔧 수정 방법 / Fix: ____________________________________

# %%
def has_overdue(days_list):
    for days in days_list:
        if days > 14:
            return True
        else:
            return False

print(has_overdue([10, 20, 5]))
# 기대 / Expected: True

# %% [markdown]
# **B7. 버그 찾기 — 식권 카드 클래스 / Find the bug — meal-card class** &nbsp;&nbsp;`(5점 / pts)`
#
# 🎯 의도: 잔액으로 카드를 만들고 결제 후 잔액 반환
# *Intent: build a card with a balance, pay, and return the remaining balance*
#
# 🐞 버그 / Bug: ________________________________________
# 🔧 수정 방법 / Fix: ____________________________________

# %%
class MealCard:
    def __init__(self, balance):
        balance = balance

    def pay(self, amount):
        self.balance -= amount
        return self.balance

card = MealCard(10000)
print(card.pay(3000))
# 기대 / Expected: 7000

# %% [markdown]
# **B8. 버그 찾기 — 요금 분할 / Find the bug — splitting a fare** &nbsp;&nbsp;`(5점 / pts)`
#
# 🎯 의도: 인원이 0명이면 0을 반환하고, 그 외에는 1인당 요금 반환
# *Intent: return 0 when there are 0 riders, otherwise the per-rider fare*
#
# 🐞 버그 / Bug: ________________________________________
# 🔧 수정 방법 / Fix: ____________________________________

# %%
def divide_fare(total, riders):
    try:
        result = total / riders
    except ValueError:
        result = 0
    return result

print(divide_fare(9000, 0))
# 기대 / Expected: 0

# %% [markdown]
# ---
# ### ✅ 끝! / Done!
# 정답과 채점 기준은 별도 파일 **`mock_final_answer_key.ipynb`** 에 있습니다.
# *Answers and the grading rubric are in the separate file **`mock_final_answer_key.ipynb`**.*
#
# 막히는 문제는 채점 기준의 **함정 표(trap table)** 에서 어떤 개념을 복습하면 되는지 확인하세요.
# *For anything you missed, the **trap table** in the rubric tells you which concept to review.*

# %%
print(0%2)
# Out:
# 0
